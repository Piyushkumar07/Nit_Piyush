# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
path=r"C:\Users\piyus\OneDrive\Data_Files\visadataset.csv"
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
***Standardization***
-
# Out:
#   Cell In[3], line 1
#     ***Standardization***
#     ^
# SyntaxError: invalid syntax

# %%
T=visa_df["prevailing_wage"]
t1=visa_df["prevailing_wage"].mean()

# %%
t2=visa_df["prevailing_wage"].std()

# %%
t=T-t2
t
# Out:
# 0        -52223.739427
# 1         30609.707673
# 2         70180.917673
# 3         30618.087673
# 4         97091.447673
#              ...
# 25475     24276.627673
# 25476    226358.847673
# 25477     93482.907673
# 25478     33338.827673
# 25479     18060.967673
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
visa_df["prevailing_wage_z_score"]=t/t2

# %%
visa_df[["prevailing_wage","prevailing_wage_z_score"]]
# Out:
#        prevailing_wage  prevailing_wage_z_score
# 0             592.2029                -0.988787
# 1           83425.6500                 0.579554
# 2          122996.8600                 1.328783
# 3           83434.0300                 0.579713
# 4          149907.3900                 1.838298
# ...                ...                      ...
# 25475       77092.5700                 0.459646
# 25476      279174.7900                 4.285805
# 25477      146298.8500                 1.769975
# 25478       86154.7700                 0.631227
# 25479       70876.9100                 0.341961
#
# [25480 rows x 2 columns]

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df["prevailing_wage"].max()
# Out:
# 319210.27

# %%
visa_df["prevailing_wage_z_score"].max()
# Out:
# 5.043824192786975

# %%
visa_df["prevailing_wage"].idxmax()
# in the pre
# Out:
# 21077

# %%
visa_df["prevailing_wage_z_score"].idxmin()
# Out:
# 20575

# %%
visa_df["prevailing_wage_z_score"].idxmax()
# Out:
# 21077

# %%
visa_df["prevailing_wage_z_score"].min()
# Out:
# -0.9999595444120494

# %%
visa_df["prevailing_wage"].min()
# Out:
# 2.1367

# %%
visa_df["prevailing_wage"].idxmin()
# Out:
# 20575

# %%
visa_df[["prevailing_wage","prevailing_wage_z_score"]].iloc[[21077,20575]]
# Out:
#        prevailing_wage  prevailing_wage_z_score
# 21077      319210.2700                 5.043824
# 20575           2.1367                -0.999960

# %% [markdown]
# ***StandaredScalar***
# - read the package
# - save the package
# - apply fit trans
# - Generally will overwrite the columns
# - because

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
visa_df["prevailing_wage_ss"]=ss.fit_transform(visa_df[["prevailing_wage"]])

# %%
visa_df["prevailing_wage_ss"]
# Out:
# 0       -1.398537
# 1        0.169835
# 2        0.919079
# 3        0.169994
# 4        1.428604
#            ...
# 25475    0.049924
# 25476    3.876159
# 25477    1.360280
# 25478    0.221509
# 25479   -0.067763
# Name: prevailing_wage_ss, Length: 25480, dtype: float64

# %%
visa_df[["prevailing_wage","prevailing_wage_z_score","prevailing_wage_ss"]]
# Out:
#        prevailing_wage  prevailing_wage_z_score  prevailing_wage_ss
# 0             592.2029                -0.988787           -1.398537
# 1           83425.6500                 0.579554            0.169835
# 2          122996.8600                 1.328783            0.919079
# 3           83434.0300                 0.579713            0.169994
# 4          149907.3900                 1.838298            1.428604
# ...                ...                      ...                 ...
# 25475       77092.5700                 0.459646            0.049924
# 25476      279174.7900                 4.285805            3.876159
# 25477      146298.8500                 1.769975            1.360280
# 25478       86154.7700                 0.631227            0.221509
# 25479       70876.9100                 0.341961           -0.067763
#
# [25480 rows x 3 columns]

# %%
path=r"C:\Users\piyus\OneDrive\Data_Files\visadataset.csv"
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# ***Min-max Scaler***

# %%
x=visa_df["prevailing_wage"]
x
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
x_min=x.min()
x_min
# Out:
# 2.1367

# %%
x_max=x.max()
x_max
# Out:
# 319210.27

# %%
dr=x-x_min

# %%
nr=x_max-x_min

# %%
minmax=dr/nr
visa_df["Min_Max"]=minmax

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
mms.fit_transform(visa_df[["prevailing_wage"]])
# Out:
# array([[0.00184853],
#        [0.2613452 ],
#        [0.385312  ],
#        ...,
#        [0.45831136],
#        [0.26989486],
#        [0.22203311]])

# %%
visa_df[["prevailing_wage","Min_Max"]]
# Out:
#        prevailing_wage   Min_Max
# 0             592.2029  0.001849
# 1           83425.6500  0.261345
# 2          122996.8600  0.385312
# 3           83434.0300  0.261371
# 4          149907.3900  0.469616
# ...                ...       ...
# 25475       77092.5700  0.241505
# 25476      279174.7900  0.874579
# 25477      146298.8500  0.458311
# 25478       86154.7700  0.269895
# 25479       70876.9100  0.222033
#
# [25480 rows x 2 columns]
